# %% [markdown]
# # **Anàlisi de les Pluges per Estació**
#
# Aquest notebook analitza l'evolució mensual de les pluges a tres estacions meteorològiques:
# - **Sabadell Centre**
# - **Sabadell Nord (Parc Agrari)**
# - **Vacarisses**
#
# Per a cada estació es mostra:
# 1. L'evolució anual de la pluja per a cada mes (gràfic 4×3)
# 2. La mitjana mensual de pluja al llarg de tot el període
# 3. Una comparació final entre les tres estacions

# %% [markdown]
# ## 1. Configuració i Funcions Auxiliars

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import warnings

warnings.filterwarnings('ignore')

month_names = {
    1: 'Gener', 2: 'Febrer', 3: 'Març', 4: 'Abril',
    5: 'Maig', 6: 'Juny', 7: 'Juliol', 8: 'Agost',
    9: 'Setembre', 10: 'Octubre', 11: 'Novembre', 12: 'Desembre'
}

# %%
def load_station_data(url):
    """Carrega les dades diàries d'una estació i afegeix columnes de temps."""
    df = pd.read_csv(url)
    if 'Unnamed: 0' in df.columns:
        df.drop(columns=['Unnamed: 0'], inplace=True)
    df['year'] = pd.to_datetime(df['date']).dt.year
    df['month'] = pd.to_datetime(df['date']).dt.month
    df['day'] = pd.to_datetime(df['date']).dt.day
    return df


def get_monthly_series(df):
    """Retorna un diccionari {mes: sèrie de pluja anual} per als 12 mesos."""
    monthly_totals = df.groupby(['year', 'month'])['rain_mm'].sum()
    return {m: monthly_totals.xs(m, level='month') for m in range(1, 13)}


def plot_monthly_grid(monthly_series, station_name):
    """Gràfic 4×3 amb l'evolució anual de la pluja per a cada mes."""
    fig, axes = plt.subplots(4, 3, figsize=(15, 10), sharex=False)
    axes = axes.flatten()

    for i in range(12):
        ax = axes[i]
        data = monthly_series[i + 1]
        data.plot.bar(ax=ax, color='#2980b9')
        ax.set_title(month_names[i + 1], fontsize=12, fontweight='bold')
        ax.set_ylim(0, 200)
        ax.xaxis.set_major_locator(MaxNLocator(integer=True))

        mean_val = data.mean()
        ax.axhline(mean_val, color='red', linestyle='--', linewidth=1)
        ax.text(
            ax.get_xlim()[1],
            mean_val,
            f'{mean_val:.1f}',
            va='center',
            ha='left',
            fontsize=8,
            color='red',
        )

    fig.suptitle(f'Evolució Anual de Pluja — {station_name}', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.show()


def plot_monthly_average(df, station_name, period):
    """Gràfic de barres amb la mitjana mensual de pluja."""
    monthly_totals = df.groupby(['year', 'month'])['rain_mm'].sum()
    month_rain = monthly_totals.groupby('month').mean()
    month_rain.index = month_rain.index.map(month_names)

    fig, ax = plt.subplots(figsize=(10, 5))
    month_rain.plot.bar(ax=ax, color='#2980b9')
    # Afegir valors a les barres
    for bar in ax.patches:
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.1f}', ha='center', va='bottom', fontsize=9)
    ax.set_xlabel('Mes', fontsize=12)
    ax.set_ylabel('Pluja (mm)', fontsize=12)
    ax.set_title(f'Mitjana Mensual de Pluja — {station_name} ({period})', fontsize=14, fontweight='bold')
    ax.tick_params(axis='x', rotation=45)
    plt.tight_layout()
    plt.show()

    return month_rain

# %% [markdown]
# ## 2. Sabadell Centre

# %% [markdown]
# ### 2.1 Càrrega de Dades

# %%
url_sbd_centre = 'https://raw.githubusercontent.com/DavidDDRC99/VO-evolution/refs/heads/main/Cleaned%20Data/Sbd_Centre_daily.csv'
df_sbd_centre = load_station_data(url_sbd_centre)

print(f"Sabadell Centre: {df_sbd_centre['year'].min()}–{df_sbd_centre['year'].max()}")
print(f"Total registres: {len(df_sbd_centre):,}")
# Out:
# Sabadell Centre: 2008–2026
# Total registres: 5,834

# %% [markdown]
# ### 2.2 Evolució Anual per Mes

# %%
monthly_sbd_c = get_monthly_series(df_sbd_centre)
plot_monthly_grid(monthly_sbd_c, 'Sabadell Centre')

# %% [markdown]
# ### 2.3 Mitjana Mensual de Pluja

# %%
avg_sbd_c = plot_monthly_average(df_sbd_centre, 'Sabadell Centre', f"{df_sbd_centre['year'].min()}-{df_sbd_centre['year'].max()}")

# %% [markdown]
# ## 3. Sabadell Nord (Parc Agrari)

# %% [markdown]
# ### 3.1 Càrrega de Dades

# %%
url_sbd_nord = 'https://raw.githubusercontent.com/DavidDDRC99/VO-evolution/refs/heads/main/Cleaned%20Data/Sbd_nord_daily.csv'
df_sbd_nord = load_station_data(url_sbd_nord)

print(f"Sabadell Nord: {df_sbd_nord['year'].min()}–{df_sbd_nord['year'].max()}")
print(f"Total registres: {len(df_sbd_nord):,}")
# Out:
# Sabadell Nord: 2008–2026
# Total registres: 6,369

# %% [markdown]
# ### 3.2 Evolució Anual per Mes

# %%
monthly_sbd_n = get_monthly_series(df_sbd_nord)
plot_monthly_grid(monthly_sbd_n, 'Sabadell Nord (Parc Agrari)')

# %% [markdown]
# ### 3.3 Mitjana Mensual de Pluja

# %%
avg_sbd_n = plot_monthly_average(df_sbd_nord, 'Sabadell Nord (Parc Agrari)', f"{df_sbd_nord['year'].min()}-{df_sbd_nord['year'].max()}")

# %% [markdown]
# ## 4. Vacarisses

# %% [markdown]
# ### 4.1 Càrrega de Dades

# %%
url_vac = 'https://raw.githubusercontent.com/DavidDDRC99/VO-evolution/refs/heads/main/Cleaned%20Data/Vacarisses_daily.csv'
df_vac = load_station_data(url_vac)

print(f"Vacarisses: {df_vac['year'].min()}–{df_vac['year'].max()}")
print(f"Total registres: {len(df_vac):,}")
# Out:
# Vacarisses: 1996–2026
# Total registres: 10,960

# %% [markdown]
# ### 4.2 Evolució Anual per Mes

# %%
monthly_vac = get_monthly_series(df_vac)
plot_monthly_grid(monthly_vac, 'Vacarisses')

# %% [markdown]
# ### 4.3 Mitjana Mensual de Pluja

# %%
avg_vac = plot_monthly_average(df_vac, 'Vacarisses', f"{df_vac['year'].min()}-{df_vac['year'].max()}")

# %% [markdown]
# ## 5. Comparació i Conclusions

# %% [markdown]
# ### 5.1 Mesos Més Plujosos (Comparació)

# %%
comparison = pd.DataFrame({
    'Sbd Centre': avg_sbd_c,
    'Sbd Nord': avg_sbd_n,
    'Vacarisses': avg_vac
})

fig, ax = plt.subplots(figsize=(10, 5))
comparison.plot(ax=ax, marker='o', linewidth=2)
ax.set_xlabel('Mes', fontsize=12)
ax.set_ylabel('Pluja mitjana (mm)', fontsize=12)
ax.set_title('Comparació de Pluja Mitjana Mensual entre Estacions', fontsize=14, fontweight='bold')
ax.tick_params(axis='x', rotation=45)
ax.legend(loc='upper right')

# Afegir valors a les línies
for column in comparison.columns:
    for i, val in enumerate(comparison[column]):
        ax.text(i, val, f'{val:.1f}', fontsize=8, ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
print("\nMesos més plujosos per estació:")
for name, avg in [('Sabadell Centre', avg_sbd_c), ('Sabadell Nord', avg_sbd_n), ('Vacarisses', avg_vac)]:
    top3 = avg.nlargest(3)
    print(f"\n  {name}:")
    for month, val in top3.items():
        print(f"    {month}: {val:.1f} mm")
# Out:
# Mesos més plujosos per estació:
#
#   Sabadell Centre:
#     Març: 67.8 mm
#     Abril: 64.0 mm
#     Octubre: 61.6 mm
#
#   Sabadell Nord:
#     Març: 69.1 mm
#     Octubre: 67.3 mm
#     Abril: 63.8 mm
#
#   Vacarisses:
#     Octubre: 79.9 mm
#     Abril: 65.7 mm
#     Setembre: 63.9 mm

# %% [markdown]
# ### 5.2 Conclusions
#
# Segons els gràfics d'evolució anual, **no hi ha una tendència clara** d'augment o disminució de les pluges al llarg dels anys a cap de les tres estacions.
#
# Tot i això, es pot observar que **hi ha mesos amb més pluja que altres** de manera consistent entre les tres estacions, indicant un patró estacional marcat.

# %%
# === Statistical trend analysis ===
import sys
sys.path.insert(0, r"C:\Users\David\Documents\VO project\VO-evolution\scripts")
from statistical_tests import (
    mk_analysis_series, mann_kendall, sens_slope, pettitt_test,
    seasonal_mann_kendall, print_mk_table
)
from scipy import stats
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 6. Trend Analysis — Statistical Tests
#
# Mann-Kendall trend test, Sen's slope, and Pettitt change-point detection on monthly and annual rainfall series.

# %% [markdown]
# ### 6.1 Seasonal Mann-Kendall (accounting for monthly seasonality)

# %%
# Seasonal Mann-Kendall on monthly rainfall
# This accounts for the seasonal cycle and tests for a monotonic trend
results_smk = []
for name, df in [('Sbd Centre', df_sbd_centre), ('Sbd Nord', df_sbd_nord), ('Vacarisses', df_vac)]:
    r = seasonal_mann_kendall(df, 'rain_mm', month_col='month', year_col='year')
    r['station'] = name
    results_smk.append(r)
    print(f"\n{'='*60}")
    print(f"  Seasonal Mann-Kendall — {name}")
    print(f"{'='*60}")
    print(f"  S_total = {r['S_total']:.1f}")
    print(f"  Z = {r['Z']:.4f}")
    print(f"  p-value = {r['p_value']:.4f}")
    print(f"  Trend: {r['trend']}")
    print(f"  Significant at alpha=0.05: {'YES' if r['p_value'] < 0.05 else 'NO'}")
    # Per-month detail
    print(f"\n  Per-month MK statistics:")
    for mr in r['monthly_results']:
        print(f"    Month {mr['month']:2d}: S = {mr['S']:+6.1f}, n = {mr['n']}")
# Out:
# ============================================================
#   Seasonal Mann-Kendall — Sbd Centre
# ============================================================
#   S_total = 26851.0
#   Z = 3.0382
#   p-value = 0.0024
#   Trend: increasing
#   Significant at alpha=0.05: YES
#
#   Per-month MK statistics:
#     Month  1: S = -1153.0, n = 539
#     Month  2: S = +3062.0, n = 437
#     Month  3: S = +5121.0, n = 397
#     Month  4: S = -3892.0, n = 478
#     Month  5: S = +3480.0, n = 504
#     Month  6: S = +2791.0, n = 421
#     Month  7: S = +2762.0, n = 456
#     Month  8: S = +4979.0, n = 480
#     Month  9: S = +2732.0, n = 495
#     Month 10: S = +3107.0, n = 549
#     Month 11: S = +1807.0, n = 529
#     Month 12: S = +2055.0, n = 549
#
# ============================================================
#   Seasonal Mann-Kendall — Sbd Nord
# ============================================================
#   S_total = 27142.0
#   Z = 2.4629
#   p-value = 0.0138
#   Trend: increasing
#   Significant at alpha=0.05: YES
#
#   Per-month MK statistics:
#     Month  1: S = +1109.0, n = 558
#     Month  2: S = +3825.0, n = 508
#     Month  3: S = +5064.0, n = 558
#     Month  4: S = -5624.0, n = 511
#     Month  5: S = +3569.0, n = 527
#     Month  6: S = +1572.0, n = 510
#     Month  7: S = +1169.0, n = 527
#     Month  8: S = +2776.0, n = 527
#     Month  9: S = +3865.0, n = 510
#     Month 10: S = +3346.0, n = 535
#     Month 11: S = +2748.0, n = 540
#     Month 12: S = +3723.0, n = 558
#
# ============================================================
#   Seasonal Mann-Kendall — Vacarisses
# ============================================================
#   S_total = 12413.0
#   Z = 0.5293
#   p-value = 0.5966
#   Trend: no trend
#   Significant at alpha=0.05: NO
#
#   Per-month MK statistics:
#     Month  1: S = -10959.0, n = 930
#     Month  2: S = +14756.0, n = 861
#     Month  3: S = +25062.0, n = 956
#     Month  4: S = +1878.0, n = 901
#     Month  5: S = -397.0, n = 930
#     Month  6: S = +8245.0, n = 898
#     Month  7: S = +6308.0, n = 925
#     Month  8: S = -8076.0, n = 927
#     Month  9: S = +2463.0, n = 896
#     Month 10: S = -2477.0, n = 907
#     Month 11: S = -6070.0, n = 899
#     Month 12: S = -18320.0, n = 930

# %% [markdown]
# ### 6.2 Mann-Kendall per Month (individual months)

# %%
# MK + Sen's slope for each month separately
month_names_en = {1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',
                  7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}

for name, df in [('Sbd Centre', df_sbd_centre), ('Sbd Nord', df_sbd_nord), ('Vacarisses', df_vac)]:
    monthly = df.groupby(['year', 'month'])['rain_mm'].sum().reset_index()
    print(f"\n{'='*60}")
    print(f"  MK per Month — {name}")
    print(f"{'='*60}")
    month_results = []
    for m in range(1, 13):
        sub = monthly[monthly['month'] == m].sort_values('year')
        years = sub['year'].values
        vals = sub['rain_mm'].values
        r = mk_analysis_series(years, vals, f'  {month_names_en[m]}')
        month_results.append(r)
    print_mk_table(month_results)
# Out:
# ============================================================
#   MK per Month — Sbd Centre
# ============================================================
# Label                                              tau   MK p-value      Slope Trend           Sig 0.05  CP year
# ----------------------------------------------------------------------------------------------------------------
#   Jan                                          -0.0980     0.6009    -0.9333 no trend               N     2012
#   Feb                                           0.1500     0.4503     0.5929 no trend               N     2023
#   Mar                                          -0.0256     0.9524    -0.2708 no trend               N     2024
#   Apr                                          -0.1167     0.5643    -1.7833 no trend               N     2021
#   May                                           0.1324     0.4896     0.8138 no trend               N     2018
#   Jun                                           0.3143     0.1142     2.4750 no trend               N     2017
#   Jul                                          -0.1238     0.5590    -0.4000 no trend               N     2015
#   Aug                                           0.1176     0.5423     0.8933 no trend               N     2012
#   Sep                                           0.3764     0.0355     4.9667 increasing             Y     2019
#   Oct                                          -0.0065     1.0000    -0.1300 no trend               N     2020
#   Nov                                           0.0065     1.0000     0.0400 no trend               N     2011
#   Dec                                           0.0787     0.6492     0.3750 no trend               N     2019
#
# ============================================================
#   MK per Month — Sbd Nord
# ============================================================
# Label                                              tau   MK p-value      Slope Trend           Sig 0.05  CP year
# ----------------------------------------------------------------------------------------------------------------
#   Jan                                          -0.0719     0.7089    -0.7400 no trend               N     2012
#   Feb                                           0.0458     0.8228     0.5000 no trend               N     2023
#   Mar                                           0.0065     1.0000     0.0333 no trend               N     2024
#   Apr                                          -0.0850     0.6540    -1.2750 no trend               N     2025
#   May                                          -0.0441     0.8393    -0.3750 no trend               N     2015
#   Jun                                          -0.0588     0.7765    -0.0938 no trend               N     2021
#   Jul                                          -0.1324     0.4896    -0.5830 no trend               N     2020
#   Aug                                           0.1324     0.4896     1.0491 no trend               N     2012
#   Sep                                           0.1107     0.5363     0.9982 no trend               N     2023
#   Oct                                          -0.0850     0.6540    -1.8786 no trend               N     2013
#   Nov                                          -0.0980     0.6009    -0.8400 no trend               N     2022
#   Dec                                           0.1049     0.5442     0.3833 no trend               N     2019
#
# ============================================================
#   MK per Month — Vacarisses
# ============================================================
# Label                                              tau   MK p-value      Slope Trend           Sig 0.05  CP year
# ----------------------------------------------------------------------------------------------------------------
#   Jan                                          -0.0506     0.6946    -0.1733 no trend               N     2000
#   Feb                                           0.2172     0.0893     0.7556 no trend               N     2003
#   Mar                                           0.2903     0.0218     1.9947 increasing             Y     2009
#   Apr                                           0.0624     0.6369     0.3591 no trend               N     2007
#   May                                           0.0805     0.5473     0.4500 no trend               N     2018
#   Jun                                           0.0092     0.9431     0.0333 no trend               N     2008
#   Jul                                           0.1059     0.4117     0.4400 no trend               N     2008
#   Aug                                          -0.2000     0.1257    -0.6333 no trend               N     2011
#   Sep                                          -0.1034     0.4358    -0.5471 no trend               N     2007
#   Oct                                          -0.1126     0.3950    -0.7700 no trend               N     2013
#   Nov                                          -0.0438     0.7345    -0.1500 no trend               N     2011
#   Dec                                          -0.1954     0.1348    -1.4750 no trend               N     2010

# %% [markdown]
# ### 6.3 Annual Rainfall Trend

# %%
# Annual rainfall totals
for name, df in [('Sbd Centre', df_sbd_centre), ('Sbd Nord', df_sbd_nord), ('Vacarisses', df_vac)]:
    annual = df.groupby('year')['rain_mm'].sum().reset_index()
    r = mk_analysis_series(annual['year'].values, annual['rain_mm'].values, f'Annual rainfall — {name}')
    print(f"\n{r['summary']}")
# Out:
# --- Annual rainfall — Sbd Centre ---
#   Mann-Kendall tau = 0.1579, p = 0.3680 (no trend)
#   Sen's slope = 11.4571 per year [-11.6000, 30.5222]
#   Pettitt change point: index=9, year~2017, p=1.0000 (not significant)
#   Significant at: alpha=0.05 no, alpha=0.01 no
#
# --- Annual rainfall — Sbd Nord ---
#   Mann-Kendall tau = -0.0292, p = 0.8903 (no trend)
#   Sen's slope = -2.5286 per year [-23.7000, 28.0667]
#   Pettitt change point: index=13, year~2021, p=1.0000 (not significant)
#   Significant at: alpha=0.05 no, alpha=0.01 no
#
# --- Annual rainfall — Vacarisses ---
#   Mann-Kendall tau = -0.0538, p = 0.6858 (no trend)
#   Sen's slope = -1.7167 per year [-9.3765, 7.4045]
#   Pettitt change point: index=25, year~2021, p=1.0000 (not significant)
#   Significant at: alpha=0.05 no, alpha=0.01 no

# %% [markdown]
# ### 6.4 Pettitt Test on Annual Series

# %%
# Pettitt change-point on annual totals
print("\nPettitt change-point detection on annual rainfall:")
for name, df in [('Sbd Centre', df_sbd_centre), ('Sbd Nord', df_sbd_nord), ('Vacarisses', df_vac)]:
    annual = df.groupby('year')['rain_mm'].sum().reset_index()
    pt = pettitt_test(annual['rain_mm'].values)
    cp_year = annual['year'].values[int(pt['cp_index'])] if not np.isnan(pt['cp_index']) else 'N/A'
    print(f"  {name:15s}: CP at year {cp_year}, U={pt['U_stat']:.1f}, "
          f"p={pt['p_value']:.4f} {'*' if pt['significant_0.05'] else ''}")
# Out:
# Pettitt change-point detection on annual rainfall:
#   Sbd Centre     : CP at year 2017, U=32.0, p=1.0000
#   Sbd Nord       : CP at year 2021, U=24.0, p=1.0000
#   Vacarisses     : CP at year 2021, U=68.0, p=1.0000

# %% [markdown]
# ## 7. Mètodes Alternatius de Detecció de Tendències
#
# A continuació es comparen els resultats del Seasonal Mann-Kendall amb tres enfocaments alternatius:
#
# 1. **STL + Mann-Kendall** — Descomposició STL (Seasonal-Trend decomposition using LOESS) del total mensual, i Mann-Kendall sobre el component de tendència.
# 2. **GAM (Splines) + bootstrap** — Regressió amb splines cúbiques naturals per modelar la tendència suau amb IC del 95% per bootstrap.
# 3. **SARIMA** — Model ARIMA estacional amb tendència lineal, per avaluar si l'autocorrelació afecta la significança.
#
# L'objectiu és validar si la tendència detectada pel Seasonal Mann-Kendall a Sabadell és robusta a la metodologia.

# %%
# === 7.1 STL Decomposition + Mann-Kendall ===
from statsmodels.tsa.seasonal import STL
import matplotlib.pyplot as plt


# Prepare monthly time series (continuous index)
def build_monthly_series(df, name):
    monthly = df.groupby(['year', 'month'])['rain_mm'].sum().reset_index()
    monthly['date'] = pd.to_datetime(monthly['year'].astype(str) + '-' + monthly['month'].astype(str) + '-01')
    monthly = monthly.sort_values('date').set_index('date')
    return monthly['rain_mm']

monthly_series = {}
for name, df in [('Sabadell Centre', df_sbd_centre), ('Sabadell Nord', df_sbd_nord), ('Vacarisses', df_vac)]:
    monthly_series[name] = build_monthly_series(df, name)
    print(f"{name}: {len(monthly_series[name])} mesos")
# Out:
# Sabadell Centre: 198 mesos
# Sabadell Nord: 211 mesos
# Vacarisses: 363 mesos

# %%
# STL decomposition + MK on trend for each station
stl_results = {}
fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

for idx, (name, series) in enumerate(monthly_series.items()):
    # STL decomposition
    stl = STL(series, period=12, robust=True)
    res = stl.fit()
    stl_results[name] = res

    # Mann-Kendall on trend component
    trend_vals = res.trend.dropna().values
    years_idx = np.arange(len(trend_vals))
    mk = mann_kendall(trend_vals)
    ss = sens_slope(trend_vals)

    # Plot
    ax = axes[idx]
    ax.plot(series.index, series.values, 'o-', color='lightblue', markersize=3, label='Original', alpha=0.5)
    ax.plot(res.trend.index, res.trend.values, 'r-', linewidth=2.5, label='STL Trend')
    ax.fill_between(res.trend.index,
                     res.trend.values - res.resid.std(),
                     res.trend.values + res.resid.std(),
                     alpha=0.2, color='red', label='±1 residu std')
    ax.set_title(f'{name} — STL Trend: tau={mk["tau"]:.3f}, p={mk["p_value"]:.4f} ({mk["trend"]})', fontsize=12)
    ax.set_ylabel('Pluja (mm)')
    ax.legend(fontsize=8)
    ax.grid(alpha=0.3)

plt.xlabel('Data')
plt.tight_layout()
plt.show()

# Print summary table
print(f"\n{'='*80}")
print(f"  STL + Mann-Kendall — Comparison with Seasonal MK")
print(f"{'='*80}")
print(f"{'Station':<20} {'MK tau':>8} {'p-value':>10} {'MK trend':<14} {'Sen slope':>10} {'SMK p-value':>14} {'SMK trend':<14}")
print("-" * 90)
smk_pvalues = {'Sabadell Centre': 0.0024, 'Sabadell Nord': 0.0138, 'Vacarisses': 0.5966}
smk_trends = {'Sabadell Centre': 'increasing', 'Sabadell Nord': 'increasing', 'Vacarisses': 'no trend'}
for name in monthly_series:
    res = stl_results[name]
    mk = mann_kendall(res.trend.dropna().values)
    ss = sens_slope(res.trend.dropna().values)
    print(f"{name:<20} {mk['tau']:>8.4f} {mk['p_value']:>10.4f} {mk['trend']:<14} {ss['slope']:>10.2f} {smk_pvalues[name]:>14.4f} {smk_trends[name]:<14}")
# Out:
# ================================================================================
#   STL + Mann-Kendall — Comparison with Seasonal MK
# ================================================================================
# Station                MK tau    p-value MK trend        Sen slope    SMK p-value SMK trend
# ------------------------------------------------------------------------------------------
# Sabadell Centre        0.0660     0.1674 no trend             0.02         0.0024 increasing
# Sabadell Nord          0.0157     0.7350 no trend             0.01         0.0138 increasing
# Vacarisses            -0.2364     0.0000 decreasing          -0.04         0.5966 no trend

# %% [markdown]
# ### Interpretació STL + MK
#
# L'STL descompon la sèrie mensual en **tendència + estacionalitat + residu**. Aplicant Mann-Kendall només al component de tendència (lliure d'estacionalitat) obtenim una validació independent del Seasonal Mann-Kendall.
#
# Si ambdós mètodes coincideixen, la confiança en la tendència detectada augmenta.

# %%
# === 7.2 GAM-like Trend with Natural Splines + Bootstrap CI ===
from scipy.interpolate import UnivariateSpline

def trend_with_bootstrap(series, n_bootstrap=1000, ci=0.95):
    """Fit spline trend + bootstrap confidence intervals."""
    x = np.arange(len(series))
    y = series.values
    mask = ~np.isnan(y)
    x, y = x[mask], y[mask]

    s = UnivariateSpline(x, y, s=len(x) * 2)
    y_fit = s(x)

    # Bootstrap residuals
    residuals = y - y_fit
    boot_fits = np.zeros((n_bootstrap, len(x)))
    for b in range(n_bootstrap):
        boot_res = np.random.choice(residuals, size=len(x), replace=True)
        boot_y = y_fit + boot_res
        boot_s = UnivariateSpline(x, boot_y, s=len(x) * 2)
        boot_fits[b] = boot_s(x)

    alpha = (1 - ci) / 2
    ci_lower = np.percentile(boot_fits, alpha * 100, axis=0)
    ci_upper = np.percentile(boot_fits, (1 - alpha) * 100, axis=0)

    return {'x': x, 'y_fit': y_fit, 'y_obs': y, 'ci_lower': ci_lower, 'ci_upper': ci_upper}

fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

for idx, (name, series) in enumerate(monthly_series.items()):
    ax = axes[idx]
    result = trend_with_bootstrap(series, n_bootstrap=500, ci=0.95)

    ax.plot(series.index[result['x']], result['y_obs'], 'o', color='lightblue', markersize=2, alpha=0.4)
    ax.plot(series.index[result['x']], result['y_fit'], 'r-', linewidth=2, label='Spline trend')
    ax.fill_between(series.index[result['x']],
                     result['ci_lower'], result['ci_upper'],
                     alpha=0.2, color='red', label=f'IC 95% bootstrap')

    # Check if CI excludes flat trend (zero slope)
    first_val = result['y_fit'][0]
    last_val = result['y_fit'][-1]
    delta = last_val - first_val
    ci_slope_lower = result['ci_lower'][-1] - result['ci_upper'][0]
    ci_slope_upper = result['ci_upper'][-1] - result['ci_lower'][0]

    ax.set_title(f'{name} — Spline trend: delta={delta:.1f} mm, IC=[{ci_slope_lower:.1f}, {ci_slope_upper:.1f}]', fontsize=12)
    ax.set_ylabel('Pluja (mm)')
    ax.legend(fontsize=8)
    ax.grid(alpha=0.3)

plt.xlabel('Data')
plt.tight_layout()
plt.show()

# %%
# === 7.3 SARIMA with trend ===
from statsmodels.tsa.statespace.sarimax import SARIMAX

def fit_sarima_trend(series, order=(1,0,1), seasonal_order=(1,0,1,12)):
    """Fit SARIMA and extract trend from smoothed series."""
    try:
        model = SARIMAX(series.fillna(method='ffill'),
                       order=order, seasonal_order=seasonal_order,
                       enforce_stationarity=False, enforce_invertibility=False)
        res = model.fit(disp=False, maxiter=200)
        trend = res.smoothed_trend
        # MK on trend
        mk = mann_kendall(trend.values)
        ss = sens_slope(trend.values)
        return {'trend': trend, 'mk': mk, 'ss': ss, 'aic': res.aic, 'bic': res.bic}
    except Exception as e:
        return None

sarima_results = {}
for name, series in monthly_series.items():
    sr = fit_sarima_trend(series)
    sarima_results[name] = sr
    if sr:
        print(f"{name}: AIC={sr['aic']:.1f}, MK tau={sr['mk']['tau']:.4f}, p={sr['mk']['p_value']:.4f} ({sr['mk']['trend']})")
    else:
        print(f"{name}: SARIMA no va convergir")
# Out:
# c:\Users\David\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\David\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Sabadell Centre: SARIMA no va convergir
# c:\Users\David\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\David\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# Sabadell Nord: SARIMA no va convergir
# c:\Users\David\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\David\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# Vacarisses: SARIMA no va convergir

# %%
# SARIMA Trend plot
fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)
for idx, (name, series) in enumerate(monthly_series.items()):
    ax = axes[idx]
    ax.plot(series.index, series.values, 'o-', color='lightblue', markersize=2, alpha=0.4, label='Original')
    if sarima_results[name]:
        trend = sarima_results[name]['trend']
        ax.plot(trend.index, trend.values, 'r-', linewidth=2, label='SARIMA trend')
        mk = sarima_results[name]['mk']
        ax.set_title(f'{name} — SARIMA: tau={mk["tau"]:.3f}, p={mk["p_value"]:.4f} ({mk["trend"]})', fontsize=12)
    else:
        ax.set_title(f'{name} — SARIMA: no va convergir', fontsize=12)
    ax.set_ylabel('Pluja (mm)')
    ax.legend(fontsize=8)
    ax.grid(alpha=0.3)
    
plt.xlabel('Data')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Resum Comparatiu de Mètodes
#
# | Mètode | Sabadell Centre | Sabadell Nord | Vacarisses |
# |--------|----------------|---------------|------------|
# | **Seasonal Mann-Kendall** | p=0.0024 **↑** | p=0.0138 **↑** | p=0.5966 → |
# | **STL + MK** | (veure output) | (veure output) | (veure output) |
# | **GAM Spline + bootstrap** | (veure output) | (veure output) | (veure output) |
# | **SARIMA + MK** | (veure output) | (veure output) | (veure output) |
#
# Si tots els mètodes coincideixen, la tendència a Sabadell (i la seva absència a Vacarisses) és un resultat robust, no un artefacte d'un test concret.
